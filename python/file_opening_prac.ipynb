# %%
str = input("enter str:")
print("u enter string",str)
# Out:
# u enter string A

# %%
ch = input("enter char:")
print("u entered char:"+ch)
# Out:
# u entered char:A

# %%
ch_single = input("enter single charachter:")
print("u entered single charachter:"+ch_single[0])
# Out:
# u entered single charachter:a

# %%
num = int(input("enter num:"))
print("entered num:",num)
# Out:
# entered num: 1

# %%
x= float(input("enter x: "))
print("your float num: ",x)
# Out:
# your float num:  300.399

# %%
a = int(input("enter a:"))
b = int(input("enter b:"))
print("no entered:",a,b,#sep="")
# Out:
# no entered:23

# %%
a = int(input("enter a:"))
b = int(input("enter b:"))
print('the sum of' ,a ,'and', b ,'is',a+b)
# Out:
# the sum of 2 and 2 is 4

# %%
a = int(input("enter a:"))
b = int(input("enter b:"))
print('the sum of{0} and {1} is {2} and product of{0} and {1} is {3}'.format(a,b,a+b,a*b))
# Out:
# the sum of2 and 2 is 4 and product of2 and 2 is 4

# %%
#progrm to covert from other system to decimal
#binary to no
str = input("enter binary no:")
x = int(str,2)
print('binary to decimal:',x)
# Out:
# binary to decimal: 13

# %%
#octal to decimal
str = input('enter octal no:')
x = int(str,8)
print('octal to decimal:',x)
# Out:
# octal to hexadecimal: 8

# %%
#hexadeciml to decimal

str = input("enter hexadecimal no:")
x = int(str,16)
print('hexadecimal to decimal:',x)
# Out:
# hexadecimal to decimal: 10

# %%
#3 var in sm line
var1,var2,var3 = [int(x) for x in input('enter 3 no:').split()]
print('sum:',var1+var2+var3)
# Out:
# sum: 60

# %%
var1,var2,var3 = [int(x) for x in input('enter 3 no:').split(',')]
print('sum:',var1+var2+var3)
# Out:
# sum: 60

# %%
lst = [x for x in input('enter 3 str:').split(',')]
print('you entered:\n',lst)
# Out:
# you entered:
#  ['amey', 'ramesh', 'suresh']

# %%
#using eval() along with input() function:
x = eval(input('enter x:'))
print('result=%d'% x)               #%d → says put an integer value here
# Out:
# result=100000000000010

# %%
#for eval use []while inputing list,() for tuple resp
lst = eval(input('enter list:'))
print('list is: ',lst)
# Out:
# list is:  ['amey', 'gujar']
